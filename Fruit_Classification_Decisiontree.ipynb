# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt

# %%
x=[[150],[160],[170],[180],[190],[200],[210],[220]]
y=[0,0,0,1,1,1,1, 1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
clf=DecisionTreeClassifier(max_depth=1)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plt.figure(figsize=(8,6))
tree.plot_tree(clf,filled=True,
               feature_names=['Weight'],
               class_names=['Apple','Orange'],
               rounded=True,
               fontsize=12)
# Out:
# [Text(0.5, 0.75, 'Weight <= 175.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Orange'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Apple'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Orange'),
#  Text(0.625, 0.5, '  False')]

# %%
y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy of the univariate decision tree: {accuracy:.2f}")
new_fruit_weight=[[175]]
prediction=clf.predict(new_fruit_weight)
print("Prediction (0=Apple,1=Orange):",prediction[0])
# Out:
# Accuracy of the univariate decision tree: 1.00
# Prediction (0=Apple,1=Orange): 0
